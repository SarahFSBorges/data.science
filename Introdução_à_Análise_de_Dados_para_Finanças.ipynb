# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahFSBorges/data.science/blob/main/Introdu%C3%A7%C3%A3o_%C3%A0_An%C3%A1lise_de_Dados_para_Finan%C3%A7as.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este exercício foi realizado com base no curso **Data Science para Finanças**
# por [sigmoidal.ai](https://sigmoidal.ai)
#
# ---
#
# <h1>Uma introdução à Análise Financeira</h1>
#
# Aplicações possíveis para Python e Finanças
#
# Seja para extrair informações de portais de investimento, analisar dados ou usar a Inteligência Artificial para decidir pontos de compra e venda, aprender Python no mundo dos investimentos é a decisão mais inteligente que você poderia ter.
#
# <center><img src="https://www.thepythoncode.com/media/articles/introduction-to-finance-and-technical-indicators-with-python.jpg" height="400px"></center>
#
# ## Ambiente Interativo
#
# Veja algumas das principais aplicações possíveis:
#
# * Criar dashboards com indicadores, múltiplos e cotações
# * Baixar automaticamente demonstrações financeiras da CVM
# * Realizar backtesting de maneira completamente automatizada
# * Enviar ordens de compra e venda de acordo com a sua estratégia
# * Analisar sentimentos de notícias para inferir como a empresa será afetada
# * Criar NFTs de maneira automatizada
# * Encontrar oportunidades únicas de NFT em marketplaces como OpenSea
# * Analisar várias criptomoedas simultaneamente
# * Otimizar sua carteira de investimentos
# * Realizar benchmarks com índices e fundos de investimento
#
# E essas são apenas algumas das possibilidades que você tem. Imagine a vantagem estratégica que isso representa em relação aos demais investidores.

# %% [markdown]
# ### Importar arquivos `csv` com as cotações do BBAS3.SA
#
# Para dar um exemplo de como é simples importar dados com o Pandas, veja o seguinte exemplo.
#
# Pelo site [Yahoo Finance](https://finance.yahoo.com/quote/BBAS3.SA/history?p=BBAS3.SA), baixei os dados da ação ordinária do Banco do Brasil (BBAS3) em formato `csv` e disponibilizei o arquivo [neste link](https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_02/BBAS3.SA.csv). Se eu abrir esse arquivo na minha máquina pelo Excel, é assim que ele vai aparecer para mim:
#
# <center><img src="https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_02/bbas3_excel.png" height="300px"></center>
#
# Importar esse mesmo arquivo usando o Pandas é tão simples quanto executar a função `pd.read_csv("local_do_arquivo.csv")`, informando qual o endereço que o `csv` se encontra (endereço na internet ou caminho na máquia local.
#
#
#
# Também é possível baixar arquivos por comandos do Terminal, criar diretórios e automatizar *pipelines*. Isso contribui mais ainda para que seu notebook seja replicável por qualquer pessoa.
#
# Vamos supor que você está usando um arquivo csv que se encontra no endereço ```https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/BBAS3.SA.csv``` e quer baixar o mesmo:

# %%
# baixar o arquivo BBAS3.SA.csv
# !wget https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/BBAS3.SA.csv
  
# ver o diretório
# !ls -l
# Out:
# --2023-01-21 19:22:57--  https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/BBAS3.SA.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17286 (17K) [text/plain]
# Saving to: ‘BBAS3.SA.csv’
#
# BBAS3.SA.csv        100%[===================>]  16.88K  --.-KB/s    in 0s
#
# 2023-01-21 19:22:57 (49.7 MB/s) - ‘BBAS3.SA.csv’ saved [17286/17286]
#
# total 24
# -rw-r--r-- 1 root root 17286 Jan 21 19:22 BBAS3.SA.csv
# drwxr-xr-x 1 root root  4096 Jan 19 14:35 sample_data

# %% [markdown]
# Pronto! O arquivo `BBAS3.SA.csv` foi importado com sucesso e já está pronto para ser usado neste *notebook*.
#
# ### Conhecendo os componentes básicos do Pandas
#
# Os dois componentes básicos que a gente deve conhecer quando lidando com Pandas são `Series` e `DataFrame`.
#
# <center><img src="https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_02/componentes_pandas.png"></center>
#
# Simplificadamente, você pode pensar o `DataFrame` como sendo uma planilha de Excel, e `Series` como sendo apenas uma coluna individual.
#
# Apesar de parecer conceitualmente simples, estas duas estruturas nativas do Pandas facilitam muito o trabalho com dados, uma vez que elas podem armazenar qualquer tipo de dado.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/BBAS3.SA.csv")

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  247.000000  247.000000  247.000000  247.000000  247.000000
# mean    45.939960   46.576397   45.154615   45.838097   44.684901
# std      7.644318    7.475109    7.858680    7.704523    7.210382
# min     24.200001   25.000000   21.910000   22.129999   22.129999
# 25%     45.425002   46.145001   44.774999   45.415001   44.072172
# 50%     48.139999   48.779999   47.560001   47.990002   46.766251
# 75%     50.535000   51.125000   49.785000   50.460001   49.133178
# max     55.599998   55.700001   54.820000   55.180000   53.052986
#
#              Volume
# count  2.470000e+02
# mean   1.405295e+07
# std    8.021174e+06
# min    5.092200e+06
# 25%    8.997050e+06
# 50%    1.198600e+07
# 75%    1.587985e+07
# max    7.397800e+07

# %%
df['Volume'].std()
# Out:
# 8021174.31326129

# %%
plt.hist(df['Volume'], bins=10);

# %%
plt.scatter(df["Open"], df["Low"])

plt.savefig('sigmoidal.png')

# %% [markdown]
# ## Bibliotecas para Análise Financeira
#
# Apesar de termos muitas opções de bibliotecas em Python para analisar dados e operar no Mercado, infelizmento o Brasil ainda oferece bem menos alternativas que países como os Estados Unidos.
#
# Claro, isso se dá pelo volume relativo e pela própria maturidade do Mercado. Mas como esse ecossistema é um organismo vivo, em constante evolução, eu recomendo a todos que sempre mantenham uma rotina de pesquisa e estudos, pois isso vai permitir você identificar qualquer novidade ou ferramenta que facilite as suas análises.
#
#
# ### Baixando as cotaçãos do Yahoo Finance com a biblioteca `yfinance`
#
# Umas das bibliotecas mais fáceis e diretas de usar, é a `yfinance`, que fornece *features* como preços de abertura, fechamento, fechamento ajustado, máxima, mínima e voluma, bastando que o usuário do serviço informe o símbolo da ação.
#
# Vale ressaltar que ela não está instalada por padrão no Google Colab, sendo necessária a sua instalação.

# %%
# instalar biblioteca que não acompanha o Colab por padrão
# !pip install yfinance -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 KB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 KB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 62.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 KB 14.9 MB/s eta 0:00:00

# %%
# importar a biblioteca yfinance
import yfinance as yf

# %%
bbas3 = yf.Ticker('BBAS3.SA')

# %%
# pegar os dados históricos de mercado
hist = bbas3.history(period="max")

# %%
hist.head()
# Out:
#                                Open      High       Low     Close  Volume  \
# Date
# 2000-01-03 00:00:00-02:00  1.179013  1.201470  1.150941  1.150941  514800
# 2000-01-04 00:00:00-02:00  1.150941  1.153748  1.096201  1.096201  314100
# 2000-01-05 00:00:00-02:00  1.094797  1.108833  1.055497  1.107430  478800
# 2000-01-06 00:00:00-02:00  1.107430  1.122869  1.094798  1.122869  205200
# 2000-01-07 00:00:00-02:00  1.122869  1.122869  1.097604  1.097604  394200
#
#                            Dividends  Stock Splits
# Date
# 2000-01-03 00:00:00-02:00        0.0           0.0
# 2000-01-04 00:00:00-02:00        0.0           0.0
# 2000-01-05 00:00:00-02:00        0.0           0.0
# 2000-01-06 00:00:00-02:00        0.0           0.0
# 2000-01-07 00:00:00-02:00        0.0           0.0

# %%
# mostrar dividendos, splits
bbas3.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2007-06-04 00:00:00-03:00   0.000000           3.0
# 2009-06-23 00:00:00-03:00   0.180221           0.0
# 2009-08-14 00:00:00-03:00   0.190873           0.0
# 2009-09-22 00:00:00-03:00   0.185397           0.0
# 2009-11-13 00:00:00-02:00   0.122897           0.0
# ...                              ...           ...
# 2022-06-14 00:00:00-03:00   0.250285           0.0
# 2022-08-23 00:00:00-03:00   0.204622           0.0
# 2022-09-13 00:00:00-03:00   0.273736           0.0
# 2022-11-22 00:00:00-03:00   0.170206           0.0
# 2022-12-13 00:00:00-03:00   0.345525           0.0
#
# [109 rows x 2 columns]

# %%
# ver informações da ação
bbas3.info
# Out:
# {'sector': 'Financial Services',
#  'fullTimeEmployees': 86430,
#  'longBusinessSummary': 'Banco do Brasil S.A., together with its subsidiaries, provides banking products and services for individuals, companies, and public sectors in Brazil and internationally. The company operates through Banking, Investments, Fund Management, Insurance (Insurance, Pension, and Capitalization), Payment Methods, and Other segments. The Banking segment offers various products and services, including deposits, loans, and other services to retail, wholesale, and public sector markets, as well as to micro-entrepreneurs. The Investments segment engages in the structuring and distribution of debts and equity instruments in primary and secondary markets; and provision of financial services. The Fund Management segment is involved in the purchase, sale, and custody of securities, as well as the management of portfolios, and investment funds and clubs. The Insurance, Pension and Capitalization segment provides life, property, and automobile insurance products, as well as private pension and capitalization plans. The Payment Methods segment is involved in the capturing, transmission, processing, and financial settlement of for electronic payment transactions. The Other segment engages in the provision of credit recovery and consortium management services; development, manufacturing, sale, rental, and integration of digital electronic systems, peripherals, programs, inputs, and computing supplies; sale of airline tickets; and lodging and organization of events. Banco do Brasil S.A. was incorporated in 1808 and is headquartered in Brasília, Brazil.',
#  'city': 'Brasília',
#  'phone': '55 80 0729 5285',
#  'state': 'DF',
#  'country': 'Brazil',
#  'companyOfficers': [],
#  'website': 'https://www.bb.com.br',
#  'maxAge': 1,
#  'address1': 'Banco do Brasil Building',
#  'industry': 'Banks—Regional',
#  'address2': 'Quadra 5, Lote B Sector of Municipalities Norte Federal District',
#  'ebitdaMargins': 0,
#  'profitMargins': 0.32994998,
#  'grossMargins': 0,
#  'operatingCashflow': -4276787968,
#  'revenueGrowth': 0.31,
#  'operatingMargins': 0.46691,
#  'ebitda': None,
#  'targetLowPrice': 42,
#  'recommendationKey': 'buy',
#  'grossProfits': 73278684000,
#  'freeCashflow': None,
#  'targetMedianPrice': 55.5,
#  'currentPrice': 40.07,
#  'earningsGrowth': 0.771,
#  'currentRatio': None,
#  'returnOnAssets': 0.014579999,
#  'numberOfAnalystOpinions': 16,
#  'targetMeanPrice': 55.63,
#  'debtToEquity': None,
#  'returnOnEquity': 0.19678,
#  'targetHighPrice': 74,
#  'totalCash': 66164162560,
#  'totalDebt': 962216919040,
#  'totalRevenue': 84060446720,
#  'totalCashPerShare': 23.186,
#  'financialCurrency': 'BRL',
#  'revenuePerShare': 29.456,
#  'quickRatio': None,
#  'recommendationMean': 2.2,
#  'exchange': 'SAO',
#  'shortName': 'BRASIL      ON      NM',
#  'longName': 'Banco do Brasil S.A.',
#  'exchangeTimezoneName': 'America/Sao_Paulo',
#  'exchangeTimezoneShortName': 'BRST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-7200000',
#  'quoteType': 'EQUITY',
#  'symbol': 'BBAS3.SA',
#  'messageBoardId': 'finmb_874155',
#  'market': 'br_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 12.067,
#  'beta3Year': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': 0.27814996,
#  'morningStarRiskRating': None,
#  'forwardEps': 11.12,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 2853639936,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 53.932,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.19668,
#  'netIncomeToCommon': 27510507520,
#  'trailingEps': 10.92,
#  'lastDividendValue': 0.345525,
#  'SandP52WeekChange': -0.09920794,
#  'priceToBook': 0.7429726,
#  'heldPercentInsiders': 0.50001,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1664496000,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': 1288822408,
#  'beta': 0.588484,
#  'enterpriseValue': 1014387965952,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1180915200,
#  'lastSplitFactor': '3:1',
#  'legalType': None,
#  'lastDividendDate': 1670889600,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.757,
#  'priceToSalesTrailing12Months': 1.3602754,
#  'dateShortInterest': None,
#  'pegRatio': 0.23,
#  'ytdReturn': None,
#  'forwardPE': 3.6034172,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 39.11,
#  'regularMarketOpen': 39.21,
#  'twoHundredDayAverage': 36.6754,
#  'trailingAnnualDividendYield': 0.101457424,
#  'payoutRatio': 0.2958,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 40.3,
#  'navPrice': None,
#  'averageDailyVolume10Day': 16697820,
#  'regularMarketPreviousClose': 39.11,
#  'fiftyDayAverage': 34.887,
#  'trailingAnnualDividendRate': 3.968,
#  'open': 39.21,
#  'toCurrency': None,
#  'averageVolume10days': 16697820,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 1.84,
#  'exDividendDate': 1670889600,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 39.11,
#  'currency': 'BRL',
#  'trailingPE': 3.6694138,
#  'regularMarketVolume': 30664500,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 114345353216,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 19229480,
#  'dayLow': 39.11,
#  'ask': 40.16,
#  'askSize': 0,
#  'volume': 30664500,
#  'fiftyTwoWeekHigh': 44.94,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 3.78,
#  'fiftyTwoWeekLow': 30.25,
#  'bid': 40.09,
#  'tradeable': False,
#  'dividendYield': 0.0458,
#  'bidSize': 0,
#  'dayHigh': 40.3,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 40.07,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com
# Insurance And Claims                                   58478000.0
# Selling And Marketing Expense                         227436000.0
# Depreciation And Amortization In Income Statement     654041000.0
# Depreciation Income Statement                         357600000.0
# Amortization                                          296441000.0
# Incomefrom Associatesand Other Participating In...    588432000.0
# Special Income Charges                                        0.0
# Other Non Operating Income Expenses                    11536000.0
# Pretax Income                                        8092933000.0
# Tax Provision                                        1560384000.0
# Net Income Common Stockholders                       5215980000.0
# Net Income                                           5351963000.0
# Net Income Including Noncontrolling Interests        5845869000.0
# Net Income Continuous Operations                     6532549000.0
# Net Income Extraordinary                             -686680000.0
# Minority Interests                                   -493906000.0
# Diluted NI Availto Com Stockholders                  5215980000.0
# Basic EPS                                                     NaN
# Diluted EPS                                                   NaN
# Basic Average Shares                                          NaN
# Diluted Average Shares                                        NaN
# Net Income From Continuing And Discontinued Ope...   6038643000.0
# Normalized Income                                    6038643000.0
# Reconciled Depreciation                               654041000.0
# Net Income From Continuing Operation Net Minori...   6038643000.0
# Total Unusual Items Excluding Goodwill                        0.0
# Total Unusual Items                                           0.0
# Tax Rate For Calcs                                       0.192808
# Tax Effect Of Unusual Items                                   0.0

# %%
bbas3.major_holders
# Out:
#         0                                      1
# 0  50.00%        % of Shares Held by All Insider
# 1  19.67%       % of Shares Held by Institutions
# 2  39.34%        % of Float Held by Institutions
# 3     492  Number of Institutions Holding Shares

# %%
bbas3.institutional_holders

# %%
bbas3.balance_sheet
# Out:
#                                                    2021-12-31  \
# Total Assets                                  1932532979000.0
# Cash Cash Equivalents And Federal Funds Sold   617593209000.0
# Cash And Cash Equivalents                      130120120000.0
# Cash Financial                                  18023001000.0
# Cash Equivalents                                          NaN
# ...                                                       ...
# Total Debt                                     172433850000.0
# Net Debt                                        42313730000.0
# Share Issued                                     2865417020.0
# Ordinary Shares Number                           2853399401.0
# Treasury Shares Number                             12017619.0
#
#                                                    2020-12-31       2019-12-31
# Total Assets                                  1725671888000.0  1469222655000.0
# Cash Cash Equivalents And Federal Funds Sold   763193600000.0   557949531000.0
# Cash And Cash Equivalents                      121393413000.0   121035397000.0
# Cash Financial                                  16784560000.0    14171188000.0
# Cash Equivalents                                          NaN       16677000.0
# ...                                                       ...              ...
# Total Debt                                     183962242000.0   285038925000.0
# Net Debt                                        62568829000.0   164003528000.0
# Share Issued                                     2865417020.0     2865417020.0
# Ordinary Shares Number                           2853241685.0     2850957851.0
# Treasury Shares Number                             12175335.0       14459169.0
#
# [64 rows x 3 columns]

# %%
bbas3.quarterly_balance_sheet
# Out:
#                                                    2022-09-30  \
# Total Assets                                  2146486987000.0
# Cash Cash Equivalents And Federal Funds Sold   649295032000.0
# Cash And Cash Equivalents                      146350921000.0
# Cash Financial                                  16773635000.0
# Cash And Due From Banks                        129577286000.0
# ...                                                       ...
# Total Debt                                     171441850000.0
# Net Debt                                        25090929000.0
# Share Issued                                     2865417020.0
# Ordinary Shares Number                           2853586645.0
# Treasury Shares Number                             11830375.0
#
#                                                    2022-06-30  \
# Total Assets                                  2047387293000.0
# Cash Cash Equivalents And Federal Funds Sold   624317461000.0
# Cash And Cash Equivalents                      124908676000.0
# Cash Financial                                  31052201000.0
# Cash And Due From Banks                         93856475000.0
# ...                                                       ...
# Total Debt                                     312591610000.0
# Net Debt                                       187682934000.0
# Share Issued                                     2865417020.0
# Ordinary Shares Number                           2853636250.0
# Treasury Shares Number                             11780770.0
#
#                                                    2022-03-31       2021-12-31
# Total Assets                                  2037602246000.0  1932532979000.0
# Cash Cash Equivalents And Federal Funds Sold   692237975000.0   617593209000.0
# Cash And Cash Equivalents                      130210270000.0   130120120000.0
# Cash Financial                                  17172960000.0    18023001000.0
# Cash And Due From Banks                        113037310000.0   112097119000.0
# ...                                                       ...              ...
# Total Debt                                     166168658000.0   172433850000.0
# Net Debt                                        35958388000.0    42313730000.0
# Share Issued                                     2865417020.0     2865417020.0
# Ordinary Shares Number                           2853636250.0     2853399401.0
# Treasury Shares Number                             11780770.0       12017619.0
#
# [63 rows x 4 columns]

# %%
bbas3.cashflow
#bbas3.quarterly_cashflow
# Out:
#                                              2021-12-31      2020-12-31  \
# Operating Cash Flow                      -46191952000.0  209330358000.0
# Net Income From Continuing Operations     28293048000.0   14389613000.0
# Gain Loss On Sale Of PPE                   -127206000.0     -79448000.0
# Net Foreign Currency Exchange Gain Loss    1141947000.0    3865262000.0
# Pension And Employee Benefit Expense      -1754070000.0    1063216000.0
# Depreciation And Amortization              2828694000.0    3155206000.0
# Depreciation                               2807423000.0    3127536000.0
# Amortization Cash Flow                       21271000.0      27670000.0
# Other Non Cash Items                       -500236000.0    -528197000.0
# Change In Working Capital                -95045411000.0  163516197000.0
# Change In Receivables                               NaN             NaN
# Change In Loans                         -107847357000.0  -71054540000.0
# Change In Other Current Assets           -12399380000.0   -5788048000.0
# Change In Other Current Liabilities        7956708000.0    1509334000.0
# Taxes Refund Paid                         -3689135000.0   -3260299000.0
# Investing Cash Flow                      -53278152000.0  -95646413000.0
# Net Investment Purchase And Sale         -49974145000.0  -93264614000.0
# Purchase Of Investment                  -271889041000.0 -219944131000.0
# Sale Of Investment                       221914896000.0  126679517000.0
# Net PPE Purchase And Sale                 -1665650000.0   -1677883000.0
# Purchase Of PPE                           -1755593000.0   -1700104000.0
# Sale Of PPE                                  89943000.0      22221000.0
# Net Intangibles Purchase And Sale         -3153679000.0   -2069300000.0
# Purchase Of Intangibles                   -3153679000.0   -2069300000.0
# Net Business Purchase And Sale             -516633000.0    -899939000.0
# Purchase Of Business                       -516633000.0    -899939000.0
# Sale Of Business                                    0.0             0.0
# Dividends Received Cfi                     2031955000.0    2265323000.0
# Financing Cash Flow                      -23778200000.0  -19751128000.0
# Net Issuance Payments Of Debt            -14359434000.0   -4854332000.0
# Net Long Term Debt Issuance              -14359434000.0   -4854332000.0
# Net Common Stock Issuance                           0.0      15268000.0
# Cash Dividends Paid                       -6454965000.0             NaN
# Common Stock Dividend Paid                          NaN             NaN
# Interest Paid Cff                                   NaN   -4199577000.0
# Net Other Financing Charges               -2294146000.0   -8841407000.0
# End Cash Position                         54494681000.0  176189508000.0
# Changes In Cash                         -123248304000.0   93932817000.0
# Effect Of Exchange Rate Changes            1553477000.0   10320668000.0
# Beginning Cash Position                  176189508000.0   71936023000.0
# Capital Expenditure                       -4909272000.0   -3769404000.0
# Free Cash Flow                           -51101224000.0  205560954000.0
#
#                                              2019-12-31
# Operating Cash Flow                       55374041000.0
# Net Income From Continuing Operations     16121177000.0
# Gain Loss On Sale Of PPE                  -3621218000.0
# Net Foreign Currency Exchange Gain Loss     697094000.0
# Pension And Employee Benefit Expense       1500444000.0
# Depreciation And Amortization              3039597000.0
# Depreciation                               2819935000.0
# Amortization Cash Flow                      219662000.0
# Other Non Cash Items                       -497404000.0
# Change In Working Capital                 11466966000.0
# Change In Receivables                      8986717000.0
# Change In Loans                            3942241000.0
# Change In Other Current Assets             -126890000.0
# Change In Other Current Liabilities        4329807000.0
# Taxes Refund Paid                         -4532583000.0
# Investing Cash Flow                      -30138449000.0
# Net Investment Purchase And Sale         -33202143000.0
# Purchase Of Investment                  -151849513000.0
# Sale Of Investment                       118647370000.0
# Net PPE Purchase And Sale                 -1581766000.0
# Purchase Of PPE                           -1651586000.0
# Sale Of PPE                                  69820000.0
# Net Intangibles Purchase And Sale         -2742067000.0
# Purchase Of Intangibles                   -2742067000.0
# Net Business Purchase And Sale             5914468000.0
# Purchase Of Business                                NaN
# Sale Of Business                           5914468000.0
# Dividends Received Cfi                     1473059000.0
# Financing Cash Flow                      -13476235000.0
# Net Issuance Payments Of Debt             -8341410000.0
# Net Long Term Debt Issuance               -8341410000.0
# Net Common Stock Issuance                  2805364000.0
# Cash Dividends Paid                       -1876305000.0
# Common Stock Dividend Paid                -1876305000.0
# Interest Paid Cff                         -7121003000.0
# Net Other Financing Charges                1057119000.0
# End Cash Position                         71936023000.0
# Changes In Cash                           11759357000.0
# Effect Of Exchange Rate Changes            -158785000.0
# Beginning Cash Position                   60335451000.0
# Capital Expenditure                       -4393653000.0
# Free Cash Flow                            50980388000.0

# %%
bbas3.earnings
# Out:
#           Revenue     Earnings
# Year
# 2018  60334372000  12862026000
# 2019  61745862000  18162067000
# 2020  58483157000  12697385000
# 2021  74031801000  19710402000

# %%
bbas3.sustainability
# Out:
#                           Value
# 2022-8
# palmOil                   False
# controversialWeapons      False
# gambling                  False
# socialScore                9.21
# nuclear                   False
# furLeather                False
# alcoholic                 False
# gmo                       False
# catholic                  False
# socialPercentile           None
# peerCount                   172
# governanceScore           10.78
# environmentPercentile      None
# animalTesting             False
# tobacco                   False
# totalEsg                  20.59
# highestControversy            2
# esgPerformance         AVG_PERF
# coal                      False
# pesticides                False
# adult                     False
# percentile                27.44
# peerGroup                 Banks
# smallArms                 False
# environmentScore           0.59
# governancePercentile       None
# militaryContract          False

# %%
#recomendações de especialistas
bbas3.recommendations

# %%
bbas3.calendar
# Out:
#                                 Value
# Earnings Date     2023-02-13 19:00:00
# Earnings Average                 2.77
# Earnings Low                     2.16
# Earnings High                    2.98
# Revenue Average           30553100000
# Revenue Low               27645800000
# Revenue High              32464600000

# %%
bbas3.news
# Out:
# [{'uuid': '8a6c70a5-4ca7-320e-919c-1e9f8f6a6ffb',
#   'title': 'The Worldwide Smart Water Management Industry is Estimated to Reach $53.6 Billion by 2031 at a 14.2% CAGR',
#   'publisher': 'PR Newswire',
#   'link': 'https://finance.yahoo.com/news/worldwide-smart-water-management-industry-192000916.html',
#   'providerPublishTime': 1674328800,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/wDGPSO44TROYKbQSONxNmQ--~B/aD00Mjt3PTQwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/prnewswire.com/e75ef6f3096d7cb6f5dd43ba82eca2fe',
#      'width': 400,
#      'height': 42,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/ozX4BjDr2.7Za22LDR9e4Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/prnewswire.com/e75ef6f3096d7cb6f5dd43ba82eca2fe',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '29fdc0a2-849a-3499-b2f3-4f3eb5474c86',
#   'title': 'Medical Disinfectant Wipes Global Market Report 2022 - by Type, Material, Distribution, Application and Region',
#   'publisher': 'PR Newswire',
#   'link': 'https://finance.yahoo.com/news/medical-disinfectant-wipes-global-market-191000926.html',
#   'providerPublishTime': 1674328200,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/wDGPSO44TROYKbQSONxNmQ--~B/aD00Mjt3PTQwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/prnewswire.com/e75ef6f3096d7cb6f5dd43ba82eca2fe',
#      'width': 400,
#      'height': 42,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/ozX4BjDr2.7Za22LDR9e4Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/prnewswire.com/e75ef6f3096d7cb6f5dd43ba82eca2fe',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '332eab62-d09f-3812-89c5-d02c6a954c73',
#   'title': "Bold Predictions for Divisional Round 'NFL GameDay Morning'",
#   'publisher': 'NFL Highlights',
#   'link': 'https://finance.yahoo.com/m/332eab62-d09f-3812-89c5-d02c6a954c73/bold-predictions-for.html',
#   'providerPublishTime': 1674328015,
#   'type': 'VIDEO',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/aXmTsBtTKrK0mVOY7OnHxw--~B/aD03MjA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/hd/cp-video-transcode/production/332eab62-d09f-3812-89c5-d02c6a954c73/2023-01-21/19-11-33/9158f755-c780-5293-94b9-a09d77d108d5/stream_1280x720x0_v2_3_0.jpg',
#      'width': 1280,
#      'height': 720,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/pgT_HaKtNflfNhaXP_BwEA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/hd/cp-video-transcode/production/332eab62-d09f-3812-89c5-d02c6a954c73/2023-01-21/19-11-33/9158f755-c780-5293-94b9-a09d77d108d5/stream_1280x720x0_v2_3_0.jpg',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '0a6b13ab-4304-3706-b5ba-dd8ebdc28cd5',
#   'title': "Peru's Machu Picchu, Inca trail ordered closed as protests flair",
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/perus-machu-picchu-inca-trail-190507166.html',
#   'providerPublishTime': 1674327907,
#   'type': 'STORY',
#   'relatedTickers': ['GLNCY']},
#  {'uuid': '56ef4e4a-9b9d-3909-bc37-8aae2fb9a481',
#   'title': 'After ranking 5th at the semi-finals and the winning of the only international wild card, Canada ranks 10th at most prestigious pastry competition on earth',
#   'publisher': 'CNW Group',
#   'link': 'https://finance.yahoo.com/news/ranking-5th-semi-finals-winning-190500230.html',
#   'providerPublishTime': 1674327900,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/i8uXV00hTD.H.5YaA1ap_Q--~B/aD0xNjt3PTE2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/cnwgroup.com/2ce3e0c0da10fcd8faad163044cc2ef1',
#      'width': 16,
#      'height': 16,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/r5Y9v4hGhaTYfEizvfUlAQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/cnwgroup.com/2ce3e0c0da10fcd8faad163044cc2ef1',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '55d4d0ee-daf4-3f7a-a039-48d62aa88753',
#   'title': 'Doug Pederson on familiarity with Andy Reid ahead of Divisional Round matchup',
#   'publisher': 'NFL Highlights',
#   'link': 'https://finance.yahoo.com/m/55d4d0ee-daf4-3f7a-a039-48d62aa88753/doug-pederson-on-familiarity.html',
#   'providerPublishTime': 1674327661,
#   'type': 'VIDEO',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/_ZuqyvZC.iDQHfcotnMxLQ--~B/aD03MjA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/hd/cp-video-transcode/production/55d4d0ee-daf4-3f7a-a039-48d62aa88753/2023-01-21/19-06-02/4e847206-8c3b-555f-97c9-8c7dbf31e28e/stream_1280x720x0_v2_3_0.jpg',
#      'width': 1280,
#      'height': 720,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/XQnkgBNWjO2ThWR8Jc7gEg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/hd/cp-video-transcode/production/55d4d0ee-daf4-3f7a-a039-48d62aa88753/2023-01-21/19-06-02/4e847206-8c3b-555f-97c9-8c7dbf31e28e/stream_1280x720x0_v2_3_0.jpg',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '88f0e99e-c924-3a84-95ee-a62cec4ee576',
#   'title': 'Cybertruck Could Boost Revenue, Says Big Tesla Investor',
#   'publisher': 'TheStreet.com',
#   'link': 'https://finance.yahoo.com/m/88f0e99e-c924-3a84-95ee-a62cec4ee576/cybertruck-could-boost.html',
#   'providerPublishTime': 1674327600,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/.vb269EtgKDFIl1E6KjixA--~B/aD0xMDgwO3c9MTkyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/thestreet.com/a88adc26ce8f542307e57153530850bc',
#      'width': 1920,
#      'height': 1080,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/LwKn1EMKDFSP8w5UeUI.fw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/thestreet.com/a88adc26ce8f542307e57153530850bc',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['TSLA']},
#  {'uuid': 'cd325ba8-6097-3aed-881f-58c09d4320d6',
#   'title': 'Patient Safety and Risk Management Software Global Market Report 2022',
#   'publisher': 'PR Newswire',
#   'link': 'https://finance.yahoo.com/news/patient-safety-risk-management-software-190000204.html',
#   'providerPublishTime': 1674327600,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/wDGPSO44TROYKbQSONxNmQ--~B/aD00Mjt3PTQwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/prnewswire.com/e75ef6f3096d7cb6f5dd43ba82eca2fe',
#      'width': 400,
#      'height': 42,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/ozX4BjDr2.7Za22LDR9e4Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/prnewswire.com/e75ef6f3096d7cb6f5dd43ba82eca2fe',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}}]

# %% [markdown]
# Para utilizar o recurso de cache, ou seja, armazenar chamadas à API de sessões anteriores, ou mesmo customizar o cabeçalho `User-agent`, utilize o código abaixo (descrito na documentação da biblioteca).

# %%
# !pip install requests_cache -q
import requests_cache

session = requests_cache.CachedSession('yfinance.cache')
session.headers['User-agent'] = 'my-program/1.0'
ticker = yf.Ticker('bbas3.sa itub4.sa', session=session)

ticker.actions
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 KB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 9.2 MB/s eta 0:00:00
# Got error from yahoo api for ticker BBAS3.SA ITUB4.SA, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BBAS3.SA ITUB4.SA: No timezone found, symbol may be delisted
# []

# %% [markdown]
# Para inicializar vários ativos instanciados em classes `Ticker`, informe os símbolos das ações da seguinte maneira.

# %%
tickers = yf.Tickers('bbas3.sa itub3.sa petr4.sa')
# returna uma tupla com objetos Ticker

# para acessar cada ativo individual
tickers.tickers['BBAS3.SA'].info
tickers.tickers['ITUB3.SA'].history(period="1mo")
# %% [markdown]
# ## Bibliotecas para Análise Quantitativa
#
# Conheça as principais bibliotecas para análise de ativos, e que serão usadas para a construção do Dashboard.

# %% [markdown]
# ### Portfolio Analytics for Quants (QuantStats)
#
# Essa é uma biblioteca para proceder com análises quantitativas, trazendo profundidade nas análises e métricas de risco.
#
# A biblioteca `quantstats` é composta de 3 módulos principais:
#
# 1. `quantstats.stats` - para calcular várias métricas de perfomance, como Índice de Sharpe, Win rate, Volatilidade, etc.
#
# 2. `quantstats.plots` - para visualizar performance, drawdowns, rolling statistics, monthly returns, entre outros.
#
# 3. `quantstats.reports` - para gerar relatórios de métricas, assim como gerar planilhas que podem ser salvas em um arquivo HTML.
#
# Assim como fizemos com a biblioteca `yfinance`, é necessário proceder com a instalação manual da biblioteca no Colab.

# %%
# instalar biblioteca que não acompanha o Colab por padrão
# !pip install quantstats -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 KB 3.7 MB/s eta 0:00:00

# %%
# importar a biblioteca quantstats
import quantstats as qs

# %%
# extender as funcionalidades para o Pandas
qs.extend_pandas()

# %%
# baixar dados para a ação ITUB3
itub3 = qs.utils.download_returns('ITUB3.SA')

# %%
# mostrar o índice de sharpe
qs.stats.sharpe(itub3)
# Out:
# 0.5525872696471921

# %%
# ou usando a funcionalidade extend_pandas
itub3.sharpe()
# Out:
# 0.5525872696471921

# %%
# visualizando a performance de uma ação
qs.plots.snapshot(itub3, title="Performance de ITUB3")
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# Uma das funcionalidades mais poderosas da biblioteca `quantstats` é a sua capacidade de gerar relatórios com apenas uma linha de código.
#
# Dentro da ferramenta você encontrará 7 tipos possíveis de relatórios:
#
# 1. `qs.reports.metrics(mode='basic', ...)`
#
# 2. `qs.reports.metrics(mode='full", ...)`
#
# 3. `qs.reports.plots(mode='basic", ...)`
#
# 4. `qs.reports.plots(mode='full", ...)`
#
# 5. `qs.reports.basic(...)`
#
# 6. `qs.reports.full(...)`
#
# 7. `qs.reports.html(...)`
#
# Um parâmetro importante que pode ser passado, é o símbolo de um ativo para servir de benchmar.

# %%
# gerar itens do relatório individualmente
itub3.monthly_returns()
# Out:
#            JAN       FEB       MAR       APR       MAY       JUN       JUL  \
# 2000 -0.092858 -0.039369  0.065574 -0.115385  0.052174  0.148759  0.028778
# 2001  0.016216 -0.079786 -0.005781  0.005814  0.098266 -0.010528  0.010640
# 2002 -0.005714  0.120689 -0.051282  0.016216 -0.069149 -0.142857 -0.213333
# 2003 -0.038461 -0.026668  0.253426 -0.021857  0.027932 -0.021739  0.027778
# 2004  0.019763  0.007753 -0.038462 -0.023999 -0.032787  0.080508 -0.019608
# 2005 -0.045714  0.152695  0.096103 -0.087677 -0.012987 -0.052632  0.027778
# 2006  0.212766  0.035088 -0.050847  0.017857 -0.070175  0.018868  0.037037
# 2007  0.030769 -0.059534 -0.031746  0.114754  0.117647  0.013158  0.038961
# 2008 -0.185933  0.144775 -0.072908  0.140947  0.041121 -0.134488  0.056419
# 2009 -0.072992 -0.043207  0.147642  0.142234  0.052161 -0.021202  0.069677
# 2010 -0.031196  0.004498  0.044726 -0.015513 -0.074037 -0.061068  0.174965
.000000e+00  0.000000  0.000000  0.000000e+00  0.000000  0.021381

# %%
# gerar itens do relatório individualmente
itub3.plot_monthly_heatmap()

# %%
# gerar itens do relatório individualmente
itub3.volatility()
# Out:
# 0.31982139344846966

# %%
# listar todas as features disponíveis
dir(qs.stats)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_ceil',
#  '_linregress',
#  '_norm',
#  '_np',
#  '_pd',
#  '_sqrt',
#  '_utils',
#  'adjusted_sortino',
#  'autocorr_penalty',
#  'avg_loss',
#  'avg_return',
#  'avg_win',
#  'best',
#  'cagr',
#  'calmar',
#  'common_sense_ratio',
#  'comp',
#  'compare',
#  'compsum',
#  'conditional_value_at_risk',
#  'consecutive_losses',
#  'consecutive_wins',
#  'cpc_index',
#  'cvar',
#  'distribution',
#  'drawdown_details',
#  'expected_return',
#  'expected_shortfall',
#  'exposure',
#  'gain_to_pain_ratio',
#  'geometric_mean',
#  'ghpr',
#  'greeks',
#  'implied_volatility',
#  'information_ratio',
#  'kelly_criterion',
#  'kurtosis',
#  'max_drawdown',
#  'monthly_returns',
#  'omega',
#  'outlier_loss_ratio',
#  'outlier_win_ratio',
#  'outliers',
#  'payoff_ratio',
#  'pct_rank',
#  'probabilistic_adjusted_sortino_ratio',
#  'probabilistic_ratio',
#  'probabilistic_sharpe_ratio',
#  'probabilistic_sortino_ratio',
#  'profit_factor',
#  'profit_ratio',
#  'r2',
#  'r_squared',
#  'rar',
#  'recovery_factor',
#  'remove_outliers',
#  'risk_of_ruin',
#  'risk_return_ratio',
#  'rolling_greeks',
#  'rolling_sharpe',
#  'rolling_sortino',
#  'rolling_volatility',
#  'ror',
#  'serenity_index',
#  'sharpe',
#  'skew',
#  'smart_sharpe',
#  'smart_sortino',
#  'sortino',
#  'tail_ratio',
#  'to_drawdown_series',
#  'treynor_ratio',
#  'ulcer_index',
#  'ulcer_performance_index',
#  'upi',
#  'value_at_risk',
#  'var',
#  'volatility',
#  'warn',
#  'win_loss_ratio',
#  'win_rate',
#  'worst']

# %% [markdown]
# ### Technical Analysis Library (TA)
#
# `ta` é uma biblioteca voltada para a análise de séries temporais financeiras (abertura, fechamento, máxima, mínima e volume).
#
# Pensada para servir como apoio às técnicas de *feature engineering* no contexto do Python, a mesma é construída em cima da conhecida biblioteca `pandas`.
#
# Assim como as anteriores, faz-se necessária sua instalação dentro do ambiente Google Colab.

# %%
# instalar ta
# !pip install ta -q
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for ta (setup.py) ... done

# %%
# importar ta
import ta

# ou importar apenas aquilo que vamos usar da biblioteca
from ta.volatility import BollingerBands

# %%
# baixar dados da PETR4 para exemplo
df = yf.download('petr4.sa')
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                             Open   High    Low  Close  Adj Close       Volume
# Date
# 2000-01-03 00:00:00-02:00  5.875  5.875  5.875  5.875   1.872027  35389440000
# 2000-01-04 00:00:00-02:00  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2000-01-05 00:00:00-02:00  5.494  5.494  5.494  5.494   1.750624  43033600000
# 2000-01-06 00:00:00-02:00  5.475  5.475  5.475  5.475   1.744570  34055680000
# 2000-01-07 00:00:00-02:00  5.500  5.500  5.500  5.500   1.752537  20912640000

# %% [markdown]
# Veja um exemplo onde facilmente conseguimos calcular as bandas superior e inferior de Bollinger.
#
# #### Bandas de Bollinger
#
# Como exemplo de aplicação das Bandas de Bollinger, vamos relembrar que elas consistem em três partes: Banda do Meio, Banda Superior e Banda Inferior.
#
# Muito utilizadas quando se busca um indicador de volatilidade de um determinado ativo, elas servem de insumos para o processo decisório de compra ou venda de um papel.
#
#
#
# <center><img src="https://origin2.cdn.componentsource.com/sites/default/files/resources/dundas/538216/Documentation/images/BollingerBands.png" height="200px"></center>
#
#
# Por padrão, é utilizado o valor de 20 períodos para seu cálculo. Mas claro que pode ser alterado de acordo com a análise desejada, sendo o período `n = 20` apenas uma recomendação do próprio Bollinger, criador do indicador.
#
# Matematicamente, os cálculos das Bandas é definido da seguinte maneira, sendo $y$ o valor do Fechamento (`Close`) da cotação.
#
# \begin{align*}
# &\mathbf{MA} = \frac{\sum\limits_{i=1}^n y_i}{n}\\
# &\mathbf{UpperBB} = MA + D \sqrt{\frac{\sum\limits_{i=1}^n (y_i - MA)^2}{n}}\\
# &\mathbf{LowerBB} = MA + D \sqrt{\frac{\sum\limits_{i=1}^n (y_i - MA)^2}{n}}
# \end{align*}
#
# Um investidor poderia desejar calcular tais valores, mas observe como tudo se torna muito simples e direto com a biblioteca `ta`.

# %%
bb = BollingerBands(close=df["Close"], window=20, window_dev=2)

# %% [markdown]
# Agora, basta apenas extrair os cálculos desse indicador. No caso, irei associar cada um deles a uma nova coluna dentro do mesmo DataFrame.

# %%
df['bb_bbm'] = bb.bollinger_mavg()
df['bb_bbh'] = bb.bollinger_hband()
df['bb_bbl'] = bb.bollinger_lband()

# %%
df.tail()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-01-16 00:00:00-03:00  24.410000  24.500000  23.830000  24.040001
# 2023-01-17 00:00:00-03:00  24.110001  25.620001  24.110001  25.520000
# 2023-01-18 00:00:00-03:00  25.840000  26.030001  25.000000  25.070000
# 2023-01-19 00:00:00-03:00  25.000000  25.950001  24.790001  25.889999
# 2023-01-20 00:00:00-03:00  25.889999  26.600000  25.420000  26.370001
#
#                            Adj Close     Volume   bb_bbm     bb_bbh     bb_bbl
# Date
# 2023-01-16 00:00:00-03:00  24.040001   31973700  23.9445  25.594112  22.294888
# 2023-01-17 00:00:00-03:00  25.520000   91797500  24.1015  25.723083  22.479917
# 2023-01-18 00:00:00-03:00  25.070000   69692900  24.2015  25.802853  22.600147
# 2023-01-19 00:00:00-03:00  25.889999   75553300  24.3175  26.049827  22.585173
# 2023-01-20 00:00:00-03:00  26.370001  114219500  24.4365  26.376967  22.496033

# %% [markdown]
# De maneira simples, com poucas linhas de código, calculamos os valores das Bandas de Bollinger.
#
# Veja como é simples e direto plotar essas informações diretamente do DataFrame.

# %%
# importar matplotlib
import matplotlib.pyplot as plt

plt.plot(df["Close"][:400])
plt.plot(df["bb_bbh"][:400])
plt.plot(df["bb_bbl"][:400])

# %% [markdown]
# A verdade é que existem bibliotecas mais modernas e interativas, mais adequadas para o contexto dos indicadores.
#
# [Repositório e documentação da biblioteca TA](https://github.com/bukosabino/ta)
